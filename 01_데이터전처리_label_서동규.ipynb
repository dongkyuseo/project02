# %% [markdown]
# # train 데이터 label 작업

# %%
# 압축파일 폴더별 정리
import os
import zipfile
path = 'D:/Workspace/04.Project/project_02/data/label/Training' # 폴더 경로 설정
file_list = os.listdir(path) # 압축파일 이름 리스트화

for file_name in file_list[2:]: # 압축파일 리스트화한걸 이름으로 하나씩 넘김
      with zipfile.ZipFile(f'{file_name}', 'r') as existing_zip: # 압축파일 경로 설정
        foldername = file_name[:-4] # 폴더 이름 추출
        os.mkdir(foldername) # 폴더 생성
        existing_zip.extractall(foldername) #압축을 풀어 폴더에 넣기

# %%
# 라벨링 파일 DF 로 변환 작업
# 작업 진행률 확인 tqdm_notebook 추가
import pandas as pd
import json
from tqdm import tqdm_notebook 
path = 'D:/Workspace/04.Project/project_02/data/label/Training' # 폴더 경로 설정
folder_list = os.listdir(path) # 폴더 이름 리스트화

# 최종 모든 라벨링 데이터 모음 데이터프레임
df_raw = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
       'disease', 'crop', 'area', 'grow', 'risk', 'points', 'name']) # 폴더내용 저장할 빈 데이터프레임 생성


       
for folder_name in tqdm_notebook(folder_list):
    print(folder_name)
    file_list = os.listdir(f'{path}/{folder_name}/')
    for file_name in file_list:
        # 각 폴더별 라벨링을 위한 임시 데이터 프레임
        df = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
       'disease', 'crop', 'area', 'grow', 'risk', 'points']) # 폴더내용 저장할 빈 데이터프레임 생성
        with open(f'{path}/{folder_name}/{file_name}', 'r') as f:
            json_data = json.load(f)
            tmp = pd.DataFrame(json_data)
            tmp = tmp[['description', 'annotations']][:15]
            tmp['description'][8:15] = tmp['annotations'][8:15] # 데이터프레임 내용 병합
            del(tmp['annotations']) # 필요없는 열 삭제
            tmp = tmp.T # 전치
            df = df.append(tmp) # df에 추가
            df['name'] = folder_name[4:] # 구분을 위한 name 열 생성
            df_raw = df_raw.append(df) # 최종 데이터 프레임에 추가

df_raw
# Out:
# <ipython-input-123-fd3c92ce8677>:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for folder_name in tqdm_notebook(folder_list):
#   0%|          | 0/20 [00:00<?, ?it/s]
# [라벨]고추_0.정상
# [라벨]고추_1.질병
# [라벨]무_0.정상
# [라벨]무_1.질병
# [라벨]배추_0.정상
# [라벨]배추_1.질병
# [라벨]애호박_0.정상
# [라벨]애호박_1.질병
# [라벨]양배추_0.정상
# [라벨]양배추_1.질병
# [라벨]오이_0.정상
# [라벨]오이_1.질병
# [라벨]잎마름병(토마토)_0.정상
# [라벨]잎마름병(토마토)_1.질병
# [라벨]콩_0.정상
# [라벨]콩_1.질병
# [라벨]파_0.정상
# [라벨]파_1.질병
# [라벨]호박_0.정상
# [라벨]호박_1.질병
#                                                          image        date  \
# description  V006_79_0_00_01_01_13_0_a01_20201102_0000_S01_...  2020/11/02
# description  V006_79_0_00_01_01_13_0_a01_20201102_0002_S01_...  2020/11/02
# description  V006_79_0_00_01_01_13_0_a01_20201103_0001_S01_...  2020/11/03
# description  V006_79_0_00_01_01_13_0_a01_20201103_0003_S01_...  2020/11/03
# description  V006_79_0_00_01_01_13_0_a05_20201111_0000_S01_...  2020/11/11
# ...                                                        ...         ...
# description     V006_79_1_20_10_03_13_3_4912b_20201126_247.jpg  2020/11/26
# description     V006_79_1_20_10_03_13_3_4912b_20201127_248.jpg  2020/11/27
# description      V006_79_1_20_10_03_13_3_7419e_20201026_4.jpeg  2020/10/26
# description      V006_79_1_20_10_03_13_3_7419e_20201027_1.jpeg  2020/10/27
# description      V006_79_1_20_10_03_13_3_7419e_20201030_3.jpeg  2020/10/30
#
#             worker height width task type region disease crop area grow risk  \
# description          3024  4032   79    0   None       0    1    1   13    0
# description          3024  4032   79    0   None       0    1    1   13    0
# description          3024  4032   79    0   None       0    1    1   13    0
# description          3024  4032   79    0   None       0    1    1   13    0
# description          3024  4032   79    0   None       0    1    1   13    0
# ...            ...    ...   ...  ...  ...    ...     ...  ...  ...  ...  ...
# description          1440  1440   79    1     14      20   10    3   13    3
# description          1440  1440   79    1     14      20   10    3   13    3
# description          3024  4032   79    1     14      20   10    3   13    3
# description          3024  4032   79    1     14      20   10    3   13    3
# description          3024  4032   79    1     14      20   10    3   13    3
#
#                                                         points     name
# description  [{'xtl': 1118, 'ytl': 1294, 'xbr': 2900, 'ybr'...  고추_0.정상
# description  [{'xtl': 1033, 'ytl': 1533, 'xbr': 2829, 'ybr'...  고추_0.정상
# description  [{'xtl': 484, 'ytl': 1227, 'xbr': 3879, 'ybr':...  고추_0.정상
# description  [{'xtl': 1241, 'ytl': 103, 'xbr': 2344, 'ybr':...  고추_0.정상
# description  [{'xtl': 1382, 'ytl': 978, 'xbr': 3226, 'ybr':...  고추_0.정상
# ...                                                        ...      ...
# description  [{'xtl': 45, 'ytl': 84, 'xbr': 1410, 'ybr': 12...  호박_1.질병
# description  [{'xtl': 201, 'ytl': 43, 'xbr': 1378, 'ybr': 1...  호박_1.질병
# description  [{'xtl': 497, 'ytl': 905, 'xbr': 2441, 'ybr': ...  호박_1.질병
# description  [{'xtl': 517, 'ytl': 1161, 'xbr': 2419, 'ybr':...  호박_1.질병
# description  [{'xtl': 502, 'ytl': 1023, 'xbr': 2487, 'ybr':...  호박_1.질병
#
# [133636 rows x 15 columns]

# %%
# 최종파일 csv 저장
df_raw.to_csv('D:/Workspace/04.Project/project_02/data/train_label.csv', index=False)

# %% [markdown]
# # validation 데이터 label 작업

# %%
# 압축파일 폴더별 정리
import os
import zipfile
path = 'D:/Workspace/04.Project/project_02/data/label/Validation' # 폴더 경로 설정
file_list = os.listdir(path) # 압축파일 이름 리스트화

for file_name in file_list[2:]: # 압축파일 리스트화한걸 이름으로 하나씩 넘김
      with zipfile.ZipFile(f'data/label/Validation/{file_name}', 'r') as existing_zip: # 압축파일 경로 설정
        foldername = file_name[:-4] # 폴더 이름 추출
        os.mkdir(f'data/label/Validation/{foldername}') # 폴더 생성
        existing_zip.extractall(f'data/label/Validation/{foldername}') #압축을 풀어 폴더에 넣기

# %%
# 라벨링 파일 DF 로 변환 작업
# 작업 진행률 확인 tqdm_notebook 추가
import pandas as pd
import json
from tqdm import tqdm_notebook 
path = 'data/label/Validation' # 폴더 경로 설정
folder_list = os.listdir(path) # 폴더 이름 리스트화

# 최종 모든 라벨링 데이터 모음 데이터프레임
df_raw = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
       'disease', 'crop', 'area', 'grow', 'risk', 'points', 'name']) # 폴더내용 저장할 빈 데이터프레임 생성


       
for folder_name in tqdm_notebook(folder_list):
    print(folder_name)
    file_list = os.listdir(f'{path}/{folder_name}/')
    for file_name in file_list:
        # 각 폴더별 라벨링을 위한 임시 데이터 프레임
        df = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
       'disease', 'crop', 'area', 'grow', 'risk', 'points']) # 폴더내용 저장할 빈 데이터프레임 생성
        with open(f'{path}/{folder_name}/{file_name}', 'r') as f:
            json_data = json.load(f)
            tmp = pd.DataFrame(json_data)
            tmp = tmp[['description', 'annotations']][:15]
            tmp['description'][8:15] = tmp['annotations'][8:15] # 데이터프레임 내용 병합
            del(tmp['annotations']) # 필요없는 열 삭제
            tmp = tmp.T # 전치
            df = df.append(tmp) # df에 추가
            df['name'] = folder_name[4:] # 구분을 위한 name 열 생성
            df_raw = df_raw.append(df) # 최종 데이터 프레임에 추가

df_raw
# Out:
# <ipython-input-5-16e1a47ecdd6>:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for folder_name in tqdm_notebook(folder_list):
#   0%|          | 0/18 [00:00<?, ?it/s]
# [라벨]무_0.정상
# [라벨]무_1.질병
# [라벨]배추_0.정상
# [라벨]배추_1.질병
# [라벨]애호박_0.정상
# [라벨]애호박_1.질병
# [라벨]양배추_0.정상
# [라벨]양배추_1.질병
# [라벨]오이_0.정상
# [라벨]오이_1.질병
# [라벨]잎마름병(토마토)_0.정상
# [라벨]잎마름병(토마토)_1.질병
# [라벨]콩_0.정상
# [라벨]콩_1.질병
# [라벨]파_0.정상
# [라벨]파_1.질병
# [라벨]호박_0.정상
# [라벨]호박_1.질병
#                                                          image        date  \
# description  V006_79_0_00_02_03_11_0_c14_20201116_0002_S01_...  2020/11/16
# description  V006_79_0_00_02_03_11_0_c15_20201110_0006_S01_...  2020/11/10
# description  V006_79_0_00_02_03_11_0_c15_20201112_0001_S01_...  2020/11/12
# description  V006_79_0_00_02_03_11_0_c16_20201110_0000_S01_...  2020/11/10
# description  V006_79_0_00_02_03_11_0_c16_20201112_0008_S01_...  2020/11/12
# ...                                                        ...         ...
# description      V006_79_1_20_10_03_13_3_4912b_20201015_48.jpg  2020/10/15
# description     V006_79_1_20_10_03_13_3_4912b_20201125_225.jpg  2020/11/25
# description     V006_79_1_20_10_03_13_3_4912b_20201125_226.jpg  2020/11/25
# description     V006_79_1_20_10_03_13_3_4912b_20201125_233.jpg  2020/11/25
# description     V006_79_1_20_10_03_13_3_4912b_20201127_250.jpg  2020/11/27
#
#             worker height width task type region disease crop area grow risk  \
# description           960   720   79    0   None       0    2    3   11    0
# description           960   720   79    0   None       0    2    3   11    0
# description           960   720   79    0   None       0    2    3   11    0
# description          3024  4032   79    0   None       0    2    3   11    0
# description          3024  4032   79    0   None       0    2    3   11    0
# ...            ...    ...   ...  ...  ...    ...     ...  ...  ...  ...  ...
# description          3024  3024   79    1     14      20   10    3   13    3
# description          1440  1440   79    1     14      20   10    3   13    3
# description          1440  1440   79    1     14      20   10    3   13    3
# description          1440  1440   79    1     14      20   10    3   13    3
# description          1440  1440   79    1     14      20   10    3   13    3
#
#                                                         points     name
# description  [{'xtl': 271, 'ytl': 233, 'xbr': 570, 'ybr': 8...   무_0.정상
# description  [{'xtl': 159, 'ytl': 394, 'xbr': 451, 'ybr': 8...   무_0.정상
# description  [{'xtl': 149, 'ytl': 209, 'xbr': 507, 'ybr': 8...   무_0.정상
# description  [{'xtl': 974, 'ytl': 1110, 'xbr': 2678, 'ybr':...   무_0.정상
# description  [{'xtl': 879, 'ytl': 692, 'xbr': 3342, 'ybr': ...   무_0.정상
# ...                                                        ...      ...
# description  [{'xtl': 202, 'ytl': 219, 'xbr': 2907, 'ybr': ...  호박_1.질병
# description  [{'xtl': 102, 'ytl': 122, 'xbr': 1374, 'ybr': ...  호박_1.질병
# description  [{'xtl': 34, 'ytl': 142, 'xbr': 1417, 'ybr': 1...  호박_1.질병
# description  [{'xtl': 61, 'ytl': 262, 'xbr': 1297, 'ybr': 1...  호박_1.질병
# description  [{'xtl': 108, 'ytl': 316, 'xbr': 1160, 'ybr': ...  호박_1.질병
#
# [15362 rows x 15 columns]

# %%
# 최종파일 csv 저장
df_raw.to_csv('data/validation_label2.csv', index=False)
